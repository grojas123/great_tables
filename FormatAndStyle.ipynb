# %%
from great_tables import GT
from great_tables.data import exibble
from great_tables import vals

gt_ex = GT(exibble[["num", "date", "time", "currency"]].head(5))

gt_ex
# Out:
# GT(_tbl_data=         num        date   time  currency
# 0     0.1111  2015-01-15  13:35     49.95
# 1     2.2220  2015-02-15  14:40     17.95
# 2    33.3300  2015-03-15  15:45      1.39
# 3   444.4000  2015-04-15  16:50  65100.00
# 4  5550.0000  2015-05-15  17:55   1325.81, _body=<great_tables._gt_data.Body object at 0x113ad6990>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='right', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x1218e92d0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x120dd4350>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'), hea ...

# %%
gt_ex = gt_ex.fmt_number(columns="num", decimals=2).fmt_currency(columns="currency")

gt_ex
# Out:
# GT(_tbl_data=         num        date   time  currency
# 0     0.1111  2015-01-15  13:35     49.95
# 1     2.2220  2015-02-15  14:40     17.95
# 2    33.3300  2015-03-15  15:45      1.39
# 3   444.4000  2015-04-15  16:50  65100.00
# 4  5550.0000  2015-05-15  17:55   1325.81, _body=<great_tables._gt_data.Body object at 0x113ad6990>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='right', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x1218e92d0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x120dd4350>, _formats=[<great_tables._gt_data.FormatInfo object at 0x121c8e050>, <great_tables._gt_data.FormatInfo object at 0x121cc4210>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', va ...

# %%
gt_ex = (
    gt_ex.fmt_date(columns="date", date_style="m_day_year")
    .fmt_time(columns="time", time_style="h_m_p")
)

gt_ex
# Out:
# GT(_tbl_data=         num        date   time  currency
# 0     0.1111  2015-01-15  13:35     49.95
# 1     2.2220  2015-02-15  14:40     17.95
# 2    33.3300  2015-03-15  15:45      1.39
# 3   444.4000  2015-04-15  16:50  65100.00
# 4  5550.0000  2015-05-15  17:55   1325.81, _body=<great_tables._gt_data.Body object at 0x113ad6990>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='right', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x1218e92d0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x120dd4350>, _formats=[<great_tables._gt_data.FormatInfo object at 0x121c8e050>, <great_tables._gt_data.FormatInfo object at 0x121cc4210>, <great_tables._gt_data.FormatInfo object at 0x121cfb510>, <great_tables._gt_data.FormatInfo object at 0x121cfb6d0>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='headi ...

# %%
gt_ex = gt_ex.fmt_date(columns="date", date_style="wday_day_month_year")

gt_ex
# Out:
# GT(_tbl_data=         num        date   time  currency
# 0     0.1111  2015-01-15  13:35     49.95
# 1     2.2220  2015-02-15  14:40     17.95
# 2    33.3300  2015-03-15  15:45      1.39
# 3   444.4000  2015-04-15  16:50  65100.00
# 4  5550.0000  2015-05-15  17:55   1325.81, _body=<great_tables._gt_data.Body object at 0x113ad6990>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='right', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x1218e92d0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x120dd4350>, _formats=[<great_tables._gt_data.FormatInfo object at 0x121c8e050>, <great_tables._gt_data.FormatInfo object at 0x121cc4210>, <great_tables._gt_data.FormatInfo object at 0x121cfb510>, <great_tables._gt_data.FormatInfo object at 0x121cfb6d0>, <great_tables._gt_data.FormatInfo object at 0x12071a710>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), head ...

# %%
gt_ex = gt_ex.fmt_currency(columns="currency", rows=[2, 3, 4], currency="GBP")

gt_ex
# Out:
# GT(_tbl_data=         num        date   time  currency
# 0     0.1111  2015-01-15  13:35     49.95
# 1     2.2220  2015-02-15  14:40     17.95
# 2    33.3300  2015-03-15  15:45      1.39
# 3   444.4000  2015-04-15  16:50  65100.00
# 4  5550.0000  2015-05-15  17:55   1325.81, _body=<great_tables._gt_data.Body object at 0x113ad6990>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='right', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x1218e92d0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x120dd4350>, _formats=[<great_tables._gt_data.FormatInfo object at 0x121c8e050>, <great_tables._gt_data.FormatInfo object at 0x121cc4210>, <great_tables._gt_data.FormatInfo object at 0x121cfb510>, <great_tables._gt_data.FormatInfo object at 0x121cfb6d0>, <great_tables._gt_data.FormatInfo object at 0x12071a710>, <great_tables._gt_data.FormatInfo object at 0x12206a710>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=Tru ...

# %%
fmt_number_1 = vals.fmt_number([1.64, 3.26, 3000.63, 236742.37])
fmt_number_2 = vals.fmt_number([1.64, 3.26, 3000.63, 236742.37], compact=True)
fmt_number_3 = vals.fmt_number([1.64, 3.26, 3000.63, 236742.37], decimals=3)
fmt_number_4 = vals.fmt_number([1.64, 3.26, 3000.63, 236742.37], pattern="[{x}]")
fmt_number_5 = vals.fmt_number([1.64, 3.26, 3000.63, 236742.37], locale="es")

print(fmt_number_1, fmt_number_2, fmt_number_3, fmt_number_4, fmt_number_5, sep="\n")
# Out:
# ['1.64', '3.26', '3,000.63', '236,742.37']
# ['1.64', '3.26', '3.00K', '236.74K']
# ['1.640', '3.260', '3,000.630', '236,742.370']
# ['[1.64]', '[3.26]', '[3,000.63]', '[236,742.37]']
# ['1,64', '3,26', '3.000,63', '236.742,37']

# %%
fmt_sci_1 = vals.fmt_scientific([0.00064, 7.353, 863454.63])
fmt_sci_2 = vals.fmt_scientific([1.64, 3.26, 3000.63], decimals=3)
fmt_sci_3 = vals.fmt_scientific([1.64, 3.26, 3000.63], exp_style="E")
fmt_sci_4 = vals.fmt_scientific([1.64, 3.26, 3000.63], locale="de")

print(fmt_sci_1, fmt_sci_2, fmt_sci_3, fmt_sci_4, sep="\n")
# Out:
# ["6.40 × 10<sup style='font-size: 65%;'>−4</sup>", '7.35', "8.63 × 10<sup style='font-size: 65%;'>5</sup>"]
# ['1.640', '3.260', "3.001 × 10<sup style='font-size: 65%;'>3</sup>"]
# ['1.64E00', '3.26E00', '3.00E30']
# ['1,64', '3,26', "3,00 × 10<sup style='font-size: 65%;'>3</sup>"]

# %%
fmt_date_1 = vals.fmt_date(
    ["2015-03-15", "2017-08-18", "2020-04-12"], date_style="wday_month_day_year"
)
fmt_date_2 = vals.fmt_date(["2015-03-15", "2017-08-18", "2020-04-12"], date_style="month_day_year")
fmt_time_1 = vals.fmt_time(["23:03", "00:55", "08:23"], time_style="h_m_p")
fmt_time_2 = vals.fmt_time(["23:03", "00:55", "08:23"], time_style="h_p")

print(fmt_date_1, fmt_date_2, fmt_time_1, fmt_time_2, sep="\n")
# Out:
# ['Sunday, March 15, 2015', 'Friday, August 18, 2017', 'Sunday, April 12, 2020']
# ['March 15, 2015', 'August 18, 2017', 'April 12, 2020']
# ['11:03 PM', '12:55 AM', '8:23 AM']
# ['11 PM', '12 AM', '8 AM']

# %%
import polars as pl

from great_tables import GT, from_column, style, loc
from great_tables.data import airquality

air_head = airquality.head()

gt_air = GT(air_head)
gt_pl_air = GT(pl.from_pandas(air_head))

# %%
gt_air.tab_style(
    style=style.fill(color="yellow"),
    locations=loc.body(columns="Temp", rows=[1, 2])
)
# Out:
# GT(_tbl_data=   Ozone  Solar_R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5, _body=<great_tables._gt_data.Body object at 0x12201d650>, _boxhead=Boxhead([ColInfo(var='Ozone', type=<ColInfoTypeEnum.default: 1>, column_label='Ozone', column_align='right', column_width=None), ColInfo(var='Solar_R', type=<ColInfoTypeEnum.default: 1>, column_label='Solar_R', column_align='right', column_width=None), ColInfo(var='Wind', type=<ColInfoTypeEnum.default: 1>, column_label='Wind', column_align='right', column_width=None), ColInfo(var='Temp', type=<ColInfoTypeEnum.default: 1>, column_label='Temp', column_align='right', column_width=None), ColInfo(var='Month', type=<ColInfoTypeEnum.default: 1>, column_label='Month', column_align='right', column_width=None), ColInfo(var='Day', type=<ColInfoTypeEnum.default: 1>, column_label='Day', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a150d0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=1, colnum=None, styles=[CellStyleFill(color='yellow')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=2, colnum=None, styles=[CellStyleFill(color='yellow')])], _locale=<great_tables._gt_data.Locale object at 0x122a16fd0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value ...

# %%
gt_air.tab_style(
    style=style.borders(sides="top", color="red", style="dashed", weight="3px"),
    locations=loc.body(rows=[1, 2])
)
# Out:
# GT(_tbl_data=   Ozone  Solar_R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5, _body=<great_tables._gt_data.Body object at 0x12201d650>, _boxhead=Boxhead([ColInfo(var='Ozone', type=<ColInfoTypeEnum.default: 1>, column_label='Ozone', column_align='right', column_width=None), ColInfo(var='Solar_R', type=<ColInfoTypeEnum.default: 1>, column_label='Solar_R', column_align='right', column_width=None), ColInfo(var='Wind', type=<ColInfoTypeEnum.default: 1>, column_label='Wind', column_align='right', column_width=None), ColInfo(var='Temp', type=<ColInfoTypeEnum.default: 1>, column_label='Temp', column_align='right', column_width=None), ColInfo(var='Month', type=<ColInfoTypeEnum.default: 1>, column_label='Month', column_align='right', column_width=None), ColInfo(var='Day', type=<ColInfoTypeEnum.default: 1>, column_label='Day', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a150d0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='Ozone', rownum=1, colnum=None, styles=[CellStyleBorders(sides='top', color='red', style='dashed', weight='3px')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Ozone', rownum=2, colnum=None, styles=[CellStyleBorders(sides='top', color='red', style='dashed', weight='3px')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Solar_R', rownum=1, colnum=None, styles=[CellStyleBorders(sides='top', color='red', style='dashed', weight='3px')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Solar_R', rownum=2, colnum=None, styles=[CellStyleBorders(sides='top', color='red', style='dashed', weight='3px')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Wind', rownum=1, colnum=None, styles=[CellStyleBorders(sides='top', color='red', style='dashed', weight='3px')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Wind', rownum=2, colnum=None, styles=[CellStyleBorders(sides='top', color='red', style='dashed', weight='3px')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=1, colnum=None, styles=[CellStyleBorders(sides='top', color='red', style='dashed', weight='3px')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=2, colnum=None, styles=[CellStyleBorders(sides='top', color='red', style='dashed', weight='3px')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Month', rownum=1, colnum=None, styles=[CellStyleBorders(sides='top', color='red', style='dashed', weight='3px')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Month', rownum=2, colnum=None, styles=[CellStyleBorders(sides='top', color='red', style='dashed', weight='3px')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Day', rownum=1, colnum=None, styles=[CellStyleBorders(sides='top', color='red', style='dashed', weight='3px')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Day', rownum=2, colnum=None, styles=[CellStyleBorders(sides='top', color='red', style='dashed', weight='3px')])], _locale=<great_tables._gt_data.Locale object at 0x122a16fd0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell',  ...

# %%
gt_air.tab_style(
    style=style.text(color="green", font="Times New Roman", weight="bold"),
    locations=loc.body(columns="Solar_R")
)
# Out:
# GT(_tbl_data=   Ozone  Solar_R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5, _body=<great_tables._gt_data.Body object at 0x12201d650>, _boxhead=Boxhead([ColInfo(var='Ozone', type=<ColInfoTypeEnum.default: 1>, column_label='Ozone', column_align='right', column_width=None), ColInfo(var='Solar_R', type=<ColInfoTypeEnum.default: 1>, column_label='Solar_R', column_align='right', column_width=None), ColInfo(var='Wind', type=<ColInfoTypeEnum.default: 1>, column_label='Wind', column_align='right', column_width=None), ColInfo(var='Temp', type=<ColInfoTypeEnum.default: 1>, column_label='Temp', column_align='right', column_width=None), ColInfo(var='Month', type=<ColInfoTypeEnum.default: 1>, column_label='Month', column_align='right', column_width=None), ColInfo(var='Day', type=<ColInfoTypeEnum.default: 1>, column_label='Day', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a150d0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='Solar_R', rownum=0, colnum=None, styles=[CellStyleText(color='green', font='Times New Roman', size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Solar_R', rownum=1, colnum=None, styles=[CellStyleText(color='green', font='Times New Roman', size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Solar_R', rownum=2, colnum=None, styles=[CellStyleText(color='green', font='Times New Roman', size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Solar_R', rownum=3, colnum=None, styles=[CellStyleText(color='green', font='Times New Roman', size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Solar_R', rownum=4, colnum=None, styles=[CellStyleText(color='green', font='Times New Roman', size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)])], _locale=<great_tables._gt_data.Locale object at 0x122a16fd0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='tabl ...

# %%
df = pl.DataFrame({"x": [1, 2], "background": ["lightyellow", "lightblue"]})

(
    GT(df)
    .tab_style(
        style=style.fill(color=from_column(column="background")),
        locations=loc.body(columns="x")
    )
)
# Out:
# GT(_tbl_data=shape: (2, 2)
# ┌─────┬─────────────┐
# │ x   ┆ background  │
# │ --- ┆ ---         │
# │ i64 ┆ str         │
# ╞═════╪═════════════╡
# │ 1   ┆ lightyellow │
# │ 2   ┆ lightblue   │
# └─────┴─────────────┘, _body=<great_tables._gt_data.Body object at 0x110361450>, _boxhead=Boxhead([ColInfo(var='x', type=<ColInfoTypeEnum.default: 1>, column_label='x', column_align='right', column_width=None), ColInfo(var='background', type=<ColInfoTypeEnum.default: 1>, column_label='background', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a48350>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='x', rownum=0, colnum=None, styles=[CellStyleFill(color='lightyellow')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='x', rownum=1, colnum=None, styles=[CellStyleFill(color='lightblue')])], _locale=<great_tables._gt_data.Locale object at 0x122a29a10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'),  ...

# %%
color_map = {
    True: "lightyellow",
    False: "lightblue"
}

with_color = air_head.assign(
    background=(air_head["Temp"] > 70).replace(color_map)
)

with_color
# Out:
#    Ozone  Solar_R  Wind  Temp  Month  Day   background
# 0   41.0    190.0   7.4    67      5    1    lightblue
# 1   36.0    118.0   8.0    72      5    2  lightyellow
# 2   12.0    149.0  12.6    74      5    3  lightyellow
# 3   18.0    313.0  11.5    62      5    4    lightblue
# 4    NaN      NaN  14.3    56      5    5    lightblue

# %%
(
    GT(with_color)
    .tab_style(
        style=style.fill(color=from_column(column="background")),
        locations=loc.body(columns="Temp")
    )
    .cols_hide(columns="background")
)
# Out:
# GT(_tbl_data=   Ozone  Solar_R  Wind  Temp  Month  Day   background
# 0   41.0    190.0   7.4    67      5    1    lightblue
# 1   36.0    118.0   8.0    72      5    2  lightyellow
# 2   12.0    149.0  12.6    74      5    3  lightyellow
# 3   18.0    313.0  11.5    62      5    4    lightblue
# 4    NaN      NaN  14.3    56      5    5    lightblue, _body=<great_tables._gt_data.Body object at 0x122a16b50>, _boxhead=Boxhead([ColInfo(var='Ozone', type=<ColInfoTypeEnum.default: 1>, column_label='Ozone', column_align='right', column_width=None), ColInfo(var='Solar_R', type=<ColInfoTypeEnum.default: 1>, column_label='Solar_R', column_align='right', column_width=None), ColInfo(var='Wind', type=<ColInfoTypeEnum.default: 1>, column_label='Wind', column_align='right', column_width=None), ColInfo(var='Temp', type=<ColInfoTypeEnum.default: 1>, column_label='Temp', column_align='right', column_width=None), ColInfo(var='Month', type=<ColInfoTypeEnum.default: 1>, column_label='Month', column_align='right', column_width=None), ColInfo(var='Day', type=<ColInfoTypeEnum.default: 1>, column_label='Day', column_align='right', column_width=None), ColInfo(var='background', type=<ColInfoTypeEnum.hidden: 4>, column_label='background', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a36f10>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=0, colnum=None, styles=[CellStyleFill(color='lightblue')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=1, colnum=None, styles=[CellStyleFill(color='lightyellow')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=2, colnum=None, styles=[CellStyleFill(color='lightyellow')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=3, colnum=None, styles=[CellStyleFill(color='lightblue')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=4, colnum=None, styles=[CellStyleFill(color='lightblue')])], _locale=<great_tables._gt_data.Locale object at 0x10fff00d0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True) ...

# %%
# A Polars expression defines color based on `Temp`
temp_color = (
    pl.when(pl.col("Temp") > 70)
    .then(pl.lit("lightyellow"))
    .otherwise(pl.lit("lightblue"))
)

gt_pl_air.tab_style(
    style=style.fill(color=temp_color),
    locations=loc.body("Temp")
)
# Out:
# GT(_tbl_data=shape: (5, 6)
# ┌───────┬─────────┬──────┬──────┬───────┬─────┐
# │ Ozone ┆ Solar_R ┆ Wind ┆ Temp ┆ Month ┆ Day │
# │ ---   ┆ ---     ┆ ---  ┆ ---  ┆ ---   ┆ --- │
# │ f64   ┆ f64     ┆ f64  ┆ i64  ┆ i64   ┆ i64 │
# ╞═══════╪═════════╪══════╪══════╪═══════╪═════╡
# │ 41.0  ┆ 190.0   ┆ 7.4  ┆ 67   ┆ 5     ┆ 1   │
# │ 36.0  ┆ 118.0   ┆ 8.0  ┆ 72   ┆ 5     ┆ 2   │
# │ 12.0  ┆ 149.0   ┆ 12.6 ┆ 74   ┆ 5     ┆ 3   │
# │ 18.0  ┆ 313.0   ┆ 11.5 ┆ 62   ┆ 5     ┆ 4   │
# │ null  ┆ null    ┆ 14.3 ┆ 56   ┆ 5     ┆ 5   │
# └───────┴─────────┴──────┴──────┴───────┴─────┘, _body=<great_tables._gt_data.Body object at 0x12202e290>, _boxhead=Boxhead([ColInfo(var='Ozone', type=<ColInfoTypeEnum.default: 1>, column_label='Ozone', column_align='right', column_width=None), ColInfo(var='Solar_R', type=<ColInfoTypeEnum.default: 1>, column_label='Solar_R', column_align='right', column_width=None), ColInfo(var='Wind', type=<ColInfoTypeEnum.default: 1>, column_label='Wind', column_align='right', column_width=None), ColInfo(var='Temp', type=<ColInfoTypeEnum.default: 1>, column_label='Temp', column_align='right', column_width=None), ColInfo(var='Month', type=<ColInfoTypeEnum.default: 1>, column_label='Month', column_align='right', column_width=None), ColInfo(var='Day', type=<ColInfoTypeEnum.default: 1>, column_label='Day', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a28890>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=0, colnum=None, styles=[CellStyleFill(color='lightblue')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=1, colnum=None, styles=[CellStyleFill(color='lightyellow')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=2, colnum=None, styles=[CellStyleFill(color='lightyellow')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=3, colnum=None, styles=[CellStyleFill(color='lightblue')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=4, colnum=None, styles=[CellStyleFill(color='lightblue')])], _locale=<great_tables._gt_data.Locale object at 0x121cf9710>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInf ...

# %%
def map_color(df):
    return (df["Temp"] > 70).map(
        {True: "lightyellow", False: "lightblue"}
    )

gt_air.tab_style(
    style=style.fill(
        color=map_color),
    locations=loc.body("Temp")
)
# Out:
# GT(_tbl_data=   Ozone  Solar_R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5, _body=<great_tables._gt_data.Body object at 0x12201d650>, _boxhead=Boxhead([ColInfo(var='Ozone', type=<ColInfoTypeEnum.default: 1>, column_label='Ozone', column_align='right', column_width=None), ColInfo(var='Solar_R', type=<ColInfoTypeEnum.default: 1>, column_label='Solar_R', column_align='right', column_width=None), ColInfo(var='Wind', type=<ColInfoTypeEnum.default: 1>, column_label='Wind', column_align='right', column_width=None), ColInfo(var='Temp', type=<ColInfoTypeEnum.default: 1>, column_label='Temp', column_align='right', column_width=None), ColInfo(var='Month', type=<ColInfoTypeEnum.default: 1>, column_label='Month', column_align='right', column_width=None), ColInfo(var='Day', type=<ColInfoTypeEnum.default: 1>, column_label='Day', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a150d0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=0, colnum=None, styles=[CellStyleFill(color='lightblue')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=1, colnum=None, styles=[CellStyleFill(color='lightyellow')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=2, colnum=None, styles=[CellStyleFill(color='lightyellow')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=3, colnum=None, styles=[CellStyleFill(color='lightblue')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=4, colnum=None, styles=[CellStyleFill(color='lightblue')])], _locale=<great_tables._gt_data.Locale object at 0x122a16fd0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss ...

# %%
import polars.selectors as cs

gt_pl_air.tab_style(
    style=style.fill(color="yellow"),
    locations=loc.body(
        columns=cs.starts_with("Te"),
        rows=pl.col("Temp") > 70
    )
)
# Out:
# GT(_tbl_data=shape: (5, 6)
# ┌───────┬─────────┬──────┬──────┬───────┬─────┐
# │ Ozone ┆ Solar_R ┆ Wind ┆ Temp ┆ Month ┆ Day │
# │ ---   ┆ ---     ┆ ---  ┆ ---  ┆ ---   ┆ --- │
# │ f64   ┆ f64     ┆ f64  ┆ i64  ┆ i64   ┆ i64 │
# ╞═══════╪═════════╪══════╪══════╪═══════╪═════╡
# │ 41.0  ┆ 190.0   ┆ 7.4  ┆ 67   ┆ 5     ┆ 1   │
# │ 36.0  ┆ 118.0   ┆ 8.0  ┆ 72   ┆ 5     ┆ 2   │
# │ 12.0  ┆ 149.0   ┆ 12.6 ┆ 74   ┆ 5     ┆ 3   │
# │ 18.0  ┆ 313.0   ┆ 11.5 ┆ 62   ┆ 5     ┆ 4   │
# │ null  ┆ null    ┆ 14.3 ┆ 56   ┆ 5     ┆ 5   │
# └───────┴─────────┴──────┴──────┴───────┴─────┘, _body=<great_tables._gt_data.Body object at 0x12202e290>, _boxhead=Boxhead([ColInfo(var='Ozone', type=<ColInfoTypeEnum.default: 1>, column_label='Ozone', column_align='right', column_width=None), ColInfo(var='Solar_R', type=<ColInfoTypeEnum.default: 1>, column_label='Solar_R', column_align='right', column_width=None), ColInfo(var='Wind', type=<ColInfoTypeEnum.default: 1>, column_label='Wind', column_align='right', column_width=None), ColInfo(var='Temp', type=<ColInfoTypeEnum.default: 1>, column_label='Temp', column_align='right', column_width=None), ColInfo(var='Month', type=<ColInfoTypeEnum.default: 1>, column_label='Month', column_align='right', column_width=None), ColInfo(var='Day', type=<ColInfoTypeEnum.default: 1>, column_label='Day', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a28890>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=1, colnum=None, styles=[CellStyleFill(color='yellow')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=2, colnum=None, styles=[CellStyleFill(color='yellow')])], _locale=<great_tables._gt_data.Locale object at 0x121cf9710>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type= ...

# %%
gt_air.tab_style(
    style=style.fill(color="yellow"),
    locations=loc.body(
        columns=lambda col_name: col_name.startswith("Te"),
        rows=lambda D: D["Temp"] > 70,
    )
)
# Out:
# GT(_tbl_data=   Ozone  Solar_R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5, _body=<great_tables._gt_data.Body object at 0x12201d650>, _boxhead=Boxhead([ColInfo(var='Ozone', type=<ColInfoTypeEnum.default: 1>, column_label='Ozone', column_align='right', column_width=None), ColInfo(var='Solar_R', type=<ColInfoTypeEnum.default: 1>, column_label='Solar_R', column_align='right', column_width=None), ColInfo(var='Wind', type=<ColInfoTypeEnum.default: 1>, column_label='Wind', column_align='right', column_width=None), ColInfo(var='Temp', type=<ColInfoTypeEnum.default: 1>, column_label='Temp', column_align='right', column_width=None), ColInfo(var='Month', type=<ColInfoTypeEnum.default: 1>, column_label='Month', column_align='right', column_width=None), ColInfo(var='Day', type=<ColInfoTypeEnum.default: 1>, column_label='Day', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a150d0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=1, colnum=None, styles=[CellStyleFill(color='yellow')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=2, colnum=None, styles=[CellStyleFill(color='yellow')])], _locale=<great_tables._gt_data.Locale object at 0x122a16fd0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value ...

# %%
gt_air.tab_style(
    style=[style.fill(color="yellow"), style.borders(sides="all")],
    locations=loc.body(columns="Temp", rows=[1, 2]),
)
# Out:
# GT(_tbl_data=   Ozone  Solar_R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5, _body=<great_tables._gt_data.Body object at 0x12201d650>, _boxhead=Boxhead([ColInfo(var='Ozone', type=<ColInfoTypeEnum.default: 1>, column_label='Ozone', column_align='right', column_width=None), ColInfo(var='Solar_R', type=<ColInfoTypeEnum.default: 1>, column_label='Solar_R', column_align='right', column_width=None), ColInfo(var='Wind', type=<ColInfoTypeEnum.default: 1>, column_label='Wind', column_align='right', column_width=None), ColInfo(var='Temp', type=<ColInfoTypeEnum.default: 1>, column_label='Temp', column_align='right', column_width=None), ColInfo(var='Month', type=<ColInfoTypeEnum.default: 1>, column_label='Month', column_align='right', column_width=None), ColInfo(var='Day', type=<ColInfoTypeEnum.default: 1>, column_label='Day', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a150d0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=1, colnum=None, styles=[CellStyleFill(color='yellow'), CellStyleBorders(sides='all', color='#000000', style='solid', weight='1px')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=2, colnum=None, styles=[CellStyleFill(color='yellow'), CellStyleBorders(sides='all', color='#000000', style='solid', weight='1px')])], _locale=<great_tables._gt_data.Locale object at 0x122a16fd0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border ...

# %%
gt_air.tab_style(
    style=style.fill(color="yellow"),
    locations=[
        loc.body(columns="Temp", rows=[1, 2]),
        loc.body(columns="Ozone", rows=[0])
    ]
)
# Out:
# GT(_tbl_data=   Ozone  Solar_R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5, _body=<great_tables._gt_data.Body object at 0x12201d650>, _boxhead=Boxhead([ColInfo(var='Ozone', type=<ColInfoTypeEnum.default: 1>, column_label='Ozone', column_align='right', column_width=None), ColInfo(var='Solar_R', type=<ColInfoTypeEnum.default: 1>, column_label='Solar_R', column_align='right', column_width=None), ColInfo(var='Wind', type=<ColInfoTypeEnum.default: 1>, column_label='Wind', column_align='right', column_width=None), ColInfo(var='Temp', type=<ColInfoTypeEnum.default: 1>, column_label='Temp', column_align='right', column_width=None), ColInfo(var='Month', type=<ColInfoTypeEnum.default: 1>, column_label='Month', column_align='right', column_width=None), ColInfo(var='Day', type=<ColInfoTypeEnum.default: 1>, column_label='Day', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a150d0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=1, colnum=None, styles=[CellStyleFill(color='yellow')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=2, colnum=None, styles=[CellStyleFill(color='yellow')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Ozone', rownum=0, colnum=None, styles=[CellStyleFill(color='yellow')])], _locale=<great_tables._gt_data.Locale object at 0x122a16fd0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo ...

# %%
import polars.selectors as cs

gt_pl_air.tab_style(
    style=style.fill(color="yellow"),
    locations=loc.body(
        columns=cs.exclude(["Month", "Day"]),
        rows=pl.col("Temp") == pl.col("Temp").max()
    )
)
# Out:
# GT(_tbl_data=shape: (5, 6)
# ┌───────┬─────────┬──────┬──────┬───────┬─────┐
# │ Ozone ┆ Solar_R ┆ Wind ┆ Temp ┆ Month ┆ Day │
# │ ---   ┆ ---     ┆ ---  ┆ ---  ┆ ---   ┆ --- │
# │ f64   ┆ f64     ┆ f64  ┆ i64  ┆ i64   ┆ i64 │
# ╞═══════╪═════════╪══════╪══════╪═══════╪═════╡
# │ 41.0  ┆ 190.0   ┆ 7.4  ┆ 67   ┆ 5     ┆ 1   │
# │ 36.0  ┆ 118.0   ┆ 8.0  ┆ 72   ┆ 5     ┆ 2   │
# │ 12.0  ┆ 149.0   ┆ 12.6 ┆ 74   ┆ 5     ┆ 3   │
# │ 18.0  ┆ 313.0   ┆ 11.5 ┆ 62   ┆ 5     ┆ 4   │
# │ null  ┆ null    ┆ 14.3 ┆ 56   ┆ 5     ┆ 5   │
# └───────┴─────────┴──────┴──────┴───────┴─────┘, _body=<great_tables._gt_data.Body object at 0x12202e290>, _boxhead=Boxhead([ColInfo(var='Ozone', type=<ColInfoTypeEnum.default: 1>, column_label='Ozone', column_align='right', column_width=None), ColInfo(var='Solar_R', type=<ColInfoTypeEnum.default: 1>, column_label='Solar_R', column_align='right', column_width=None), ColInfo(var='Wind', type=<ColInfoTypeEnum.default: 1>, column_label='Wind', column_align='right', column_width=None), ColInfo(var='Temp', type=<ColInfoTypeEnum.default: 1>, column_label='Temp', column_align='right', column_width=None), ColInfo(var='Month', type=<ColInfoTypeEnum.default: 1>, column_label='Month', column_align='right', column_width=None), ColInfo(var='Day', type=<ColInfoTypeEnum.default: 1>, column_label='Day', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a28890>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='Ozone', rownum=2, colnum=None, styles=[CellStyleFill(color='yellow')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Solar_R', rownum=2, colnum=None, styles=[CellStyleFill(color='yellow')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Wind', rownum=2, colnum=None, styles=[CellStyleFill(color='yellow')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='Temp', rownum=2, colnum=None, styles=[CellStyleFill(color='yellow')])], _locale=<great_tables._gt_data.Locale object at 0x121cf9710>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='# ...

# %%
from great_tables import GT
import polars as pl

simple_df = pl.DataFrame(
    {
        "integer": [1, 2, 3, 4, 5],
        "float": [2.3, 1.3, 5.1, None, 4.4],
        "category": ["one", "two", "three", "one", "three"],
    }
)

GT(simple_df).data_color()
# Out:
# GT(_tbl_data=shape: (5, 3)
# ┌─────────┬───────┬──────────┐
# │ integer ┆ float ┆ category │
# │ ---     ┆ ---   ┆ ---      │
# │ i64     ┆ f64   ┆ str      │
# ╞═════════╪═══════╪══════════╡
# │ 1       ┆ 2.3   ┆ one      │
# │ 2       ┆ 1.3   ┆ two      │
# │ 3       ┆ 5.1   ┆ three    │
# │ 4       ┆ null  ┆ one      │
# │ 5       ┆ 4.4   ┆ three    │
# └─────────┴───────┴──────────┘, _body=<great_tables._gt_data.Body object at 0x122004250>, _boxhead=Boxhead([ColInfo(var='integer', type=<ColInfoTypeEnum.default: 1>, column_label='integer', column_align='right', column_width=None), ColInfo(var='float', type=<ColInfoTypeEnum.default: 1>, column_label='float', column_align='right', column_width=None), ColInfo(var='category', type=<ColInfoTypeEnum.default: 1>, column_label='category', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122adb050>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=0, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#000000')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#80b156')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#25bce6')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#d73a91')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#9e9e9e')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#75bc53')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=1, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#000000')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#9e9e9e')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#808080')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#e99142')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='category', rownum=0, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#000000')]), StyleInfo(locname= ...

# %%
GT(simple_df).data_color(palette=["blue", "red"])
# Out:
# GT(_tbl_data=shape: (5, 3)
# ┌─────────┬───────┬──────────┐
# │ integer ┆ float ┆ category │
# │ ---     ┆ ---   ┆ ---      │
# │ i64     ┆ f64   ┆ str      │
# ╞═════════╪═══════╪══════════╡
# │ 1       ┆ 2.3   ┆ one      │
# │ 2       ┆ 1.3   ┆ two      │
# │ 3       ┆ 5.1   ┆ three    │
# │ 4       ┆ null  ┆ one      │
# │ 5       ┆ 4.4   ┆ three    │
# └─────────┴───────┴──────────┘, _body=<great_tables._gt_data.Body object at 0x122adfa90>, _boxhead=Boxhead([ColInfo(var='integer', type=<ColInfoTypeEnum.default: 1>, column_label='integer', column_align='right', column_width=None), ColInfo(var='float', type=<ColInfoTypeEnum.default: 1>, column_label='float', column_align='right', column_width=None), ColInfo(var='category', type=<ColInfoTypeEnum.default: 1>, column_label='category', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a3bb50>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=0, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#0000ff')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=1, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#4000bf')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=2, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#800080')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=3, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#bf0040')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#ff0000')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=0, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#4300bc')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=1, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#0000ff')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#ff0000')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#808080')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=4, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#d0002f')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='category', rownum=0, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#0000ff')]), StyleInfo(locname= ...

# %%
GT(simple_df).data_color(palette=["blue", "red"], na_color="#FFE4C4")
# Out:
# GT(_tbl_data=shape: (5, 3)
# ┌─────────┬───────┬──────────┐
# │ integer ┆ float ┆ category │
# │ ---     ┆ ---   ┆ ---      │
# │ i64     ┆ f64   ┆ str      │
# ╞═════════╪═══════╪══════════╡
# │ 1       ┆ 2.3   ┆ one      │
# │ 2       ┆ 1.3   ┆ two      │
# │ 3       ┆ 5.1   ┆ three    │
# │ 4       ┆ null  ┆ one      │
# │ 5       ┆ 4.4   ┆ three    │
# └─────────┴───────┴──────────┘, _body=<great_tables._gt_data.Body object at 0x122a85dd0>, _boxhead=Boxhead([ColInfo(var='integer', type=<ColInfoTypeEnum.default: 1>, column_label='integer', column_align='right', column_width=None), ColInfo(var='float', type=<ColInfoTypeEnum.default: 1>, column_label='float', column_align='right', column_width=None), ColInfo(var='category', type=<ColInfoTypeEnum.default: 1>, column_label='category', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122adb690>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=0, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#0000ff')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=1, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#4000bf')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=2, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#800080')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=3, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#bf0040')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#ff0000')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=0, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#4300bc')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=1, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#0000ff')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#ff0000')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#FFE4C4')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=4, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#d0002f')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='category', rownum=0, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#0000ff')]), StyleInfo(locname= ...

# %%
(
    GT(simple_df)
    .data_color(
        columns=["integer", "float"],
        palette=["blue", "red"],
        domain=[0, 10],
        na_color="white"
    )
)
# Out:
# GT(_tbl_data=shape: (5, 3)
# ┌─────────┬───────┬──────────┐
# │ integer ┆ float ┆ category │
# │ ---     ┆ ---   ┆ ---      │
# │ i64     ┆ f64   ┆ str      │
# ╞═════════╪═══════╪══════════╡
# │ 1       ┆ 2.3   ┆ one      │
# │ 2       ┆ 1.3   ┆ two      │
# │ 3       ┆ 5.1   ┆ three    │
# │ 4       ┆ null  ┆ one      │
# │ 5       ┆ 4.4   ┆ three    │
# └─────────┴───────┴──────────┘, _body=<great_tables._gt_data.Body object at 0x122ae9050>, _boxhead=Boxhead([ColInfo(var='integer', type=<ColInfoTypeEnum.default: 1>, column_label='integer', column_align='right', column_width=None), ColInfo(var='float', type=<ColInfoTypeEnum.default: 1>, column_label='float', column_align='right', column_width=None), ColInfo(var='category', type=<ColInfoTypeEnum.default: 1>, column_label='category', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122add750>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=0, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#1a00e6')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=1, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#3300cc')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=2, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#4c00b2')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=3, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#660099')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='integer', rownum=4, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#800080')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=0, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#3b00c4')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=1, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#2100de')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=2, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#82007d')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#FFFFFF')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='float', rownum=4, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#70008f')])], _locale=<great_tables._gt_data.Locale object at 0x10fff1310>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='ta ...

# %%
from great_tables import html
from great_tables.data import sza
import polars.selectors as cs

sza_pivot = (
    pl.from_pandas(sza)
    .filter((pl.col("latitude") == "20") & (pl.col("tst") <= "1200"))
    .select(pl.col("*").exclude("latitude"))
    .drop_nulls()
    .pivot(values="sza", index="month", on="tst", sort_columns=True)
)

(
    GT(sza_pivot, rowname_col="month")
    .data_color(
        domain=[90, 0],
        palette=["rebeccapurple", "white", "orange"],
        na_color="white",
    )
    .tab_header(
        title="Solar Zenith Angles from 05:30 to 12:00",
        subtitle=html("Average monthly values at latitude of 20&deg;N."),
    )
)
# Out:
# GT(_tbl_data=shape: (12, 15)
# ┌───────┬──────┬──────┬──────┬───┬──────┬──────┬──────┬──────┐
# │ month ┆ 0530 ┆ 0600 ┆ 0630 ┆ … ┆ 1030 ┆ 1100 ┆ 1130 ┆ 1200 │
# │ ---   ┆ ---  ┆ ---  ┆ ---  ┆   ┆ ---  ┆ ---  ┆ ---  ┆ ---  │
# │ str   ┆ f64  ┆ f64  ┆ f64  ┆   ┆ f64  ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪══════╪══════╪══════╪═══╪══════╪══════╪══════╪══════╡
# │ jan   ┆ null ┆ null ┆ null ┆ … ┆ 48.3 ┆ 45.5 ┆ 43.6 ┆ 43.0 │
# │ feb   ┆ null ┆ null ┆ 88.9 ┆ … ┆ 43.1 ┆ 40.0 ┆ 37.8 ┆ 37.2 │
# │ mar   ┆ null ┆ null ┆ 85.7 ┆ … ┆ 35.5 ┆ 31.4 ┆ 28.6 ┆ 27.7 │
# │ apr   ┆ null ┆ 88.5 ┆ 81.5 ┆ … ┆ 26.9 ┆ 21.3 ┆ 17.2 ┆ 15.5 │
# │ may   ┆ null ┆ 85.0 ┆ 78.2 ┆ … ┆ 26.1 ┆ 15.2 ┆ 8.8  ┆ 5.0  │
# │ …     ┆ …    ┆ …    ┆ …    ┆ … ┆ …    ┆ …    ┆ …    ┆ …    │
# │ aug   ┆ null ┆ 83.8 ┆ 77.1 ┆ … ┆ 21.3 ┆ 14.3 ┆ 7.3  ┆ 1.9  │
# │ sep   ┆ null ┆ 87.2 ┆ 80.2 ┆ … ┆ 24.7 ┆ 18.6 ┆ 13.7 ┆ 11.6 │
# │ oct   ┆ null ┆ null ┆ 84.1 ┆ … ┆ 32.0 ┆ 27.4 ┆ 24.3 ┆ 23.1 │
# │ nov   ┆ null ┆ null ┆ 87.8 ┆ … ┆ 40.7 ┆ 37.4 ┆ 35.1 ┆ 34.4 │
# │ dec   ┆ null ┆ null ┆ null ┆ … ┆ 47.2 ┆ 44.2 ┆ 42.4 ┆ 41.8 │
# └───────┴──────┴──────┴──────┴───┴──────┴──────┴──────┴──────┘, _body=<great_tables._gt_data.Body object at 0x122b4de90>, _boxhead=Boxhead([ColInfo(var='month', type=<ColInfoTypeEnum.stub: 2>, column_label='month', column_align='left', column_width=None), ColInfo(var='0530', type=<ColInfoTypeEnum.default: 1>, column_label='0530', column_align='right', column_width=None), ColInfo(var='0600', type=<ColInfoTypeEnum.default: 1>, column_label='0600', column_align='right', column_width=None), ColInfo(var='0630', type=<ColInfoTypeEnum.default: 1>, column_label='0630', column_align='right', column_width=None), ColInfo(var='0700', type=<ColInfoTypeEnum.default: 1>, column_label='0700', column_align='right', column_width=None), ColInfo(var='0730', type=<ColInfoTypeEnum.default: 1>, column_label='0730', column_align='right', column_width=None), ColInfo(var='0800', type=<ColInfoTypeEnum.default: 1>, column_label='0800', column_align='right', column_width=None), ColInfo(var='0830', type=<ColInfoTypeEnum.default: 1>, column_label='0830', column_align='right', column_width=None), ColInfo(var='0900', type=<ColInfoTypeEnum.default: 1>, column_label='0900', column_align='right', column_width=None), ColInfo(var='0930', type=<ColInfoTypeEnum.default: 1>, column_label='0930', column_align='right', column_width=None), ColInfo(var='1000', type=<ColInfoTypeEnum.default: 1>, column_label='1000', column_align='right', column_width=None), ColInfo(var='1030', type=<ColInfoTypeEnum.default: 1>, column_label='1030', column_align='right', column_width=None), ColInfo(var='1100', type=<ColInfoTypeEnum.default: 1>, column_label='1100', column_align='right', column_width=None), ColInfo(var='1130', type=<ColInfoTypeEnum.default: 1>, column_label='1130', column_align='right', column_width=None), ColInfo(var='1200', type=<ColInfoTypeEnum.default: 1>, column_label='1200', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122b4d990>, _spanners=Spanners([]), _heading=Heading(title='Solar Zenith Angles from 05:30 to 12:00', subtitle=Html(text='Average monthly values at latitude of 20&deg;N.'), preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='month', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#FFFFFF')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='month', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#FFFFFF')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='month', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#FFFFFF')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='month', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#FFFFFF')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='month', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#FFFFFF')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='month', rownum=5, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#FFFFFF')]), St ...

# %%
from great_tables import GT, exibble

gt_ex = (
    GT(exibble.head(5), rowname_col="row", groupname_col="group")
    .tab_header("THE HEADING", "(a subtitle)")
    .tab_stubhead("THE STUBHEAD")
    .tab_source_note("THE SOURCE NOTE")
)

gt_ex
# Out:
# GT(_tbl_data=         num     char   fctr        date   time          datetime  currency  \
# 0     0.1111  apricot    one  2015-01-15  13:35  2018-01-01 02:22     49.95
# 1     2.2220   banana    two  2015-02-15  14:40  2018-02-02 14:33     17.95
# 2    33.3300  coconut  three  2015-03-15  15:45  2018-03-03 03:44      1.39
# 3   444.4000   durian   four  2015-04-15  16:50  2018-04-04 15:55  65100.00
# 4  5550.0000      NaN   five  2015-05-15  17:55  2018-05-05 04:00   1325.81
#
#      row  group
# 0  row_1  grp_a
# 1  row_2  grp_a
# 2  row_3  grp_a
# 3  row_4  grp_a
# 4  row_5  grp_b  , _body=<great_tables._gt_data.Body object at 0x122a3b910>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='fctr', type=<ColInfoTypeEnum.default: 1>, column_label='fctr', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='right', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a3a650>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b4d650>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True,  ...

# %%
(
    gt_ex
    .tab_options(
        container_width = "100%",
        table_background_color="lightblue",
        heading_background_color = "gold",
        column_labels_background_color="aquamarine",
        row_group_background_color="lightyellow",
        stub_background_color="lightgreen",
        source_notes_background_color="#f1e2af",
    )
)
# Out:
# GT(_tbl_data=         num     char   fctr        date   time          datetime  currency  \
# 0     0.1111  apricot    one  2015-01-15  13:35  2018-01-01 02:22     49.95
# 1     2.2220   banana    two  2015-02-15  14:40  2018-02-02 14:33     17.95
# 2    33.3300  coconut  three  2015-03-15  15:45  2018-03-03 03:44      1.39
# 3   444.4000   durian   four  2015-04-15  16:50  2018-04-04 15:55  65100.00
# 4  5550.0000      NaN   five  2015-05-15  17:55  2018-05-05 04:00   1325.81
#
#      row  group
# 0  row_1  grp_a
# 1  row_2  grp_a
# 2  row_3  grp_a
# 3  row_4  grp_a
# 4  row_5  grp_b  , _body=<great_tables._gt_data.Body object at 0x122a3b910>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='fctr', type=<ColInfoTypeEnum.default: 1>, column_label='fctr', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='right', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a3a650>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b4d650>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='lightblue'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True ...

# %%
gt_ex.tab_options(
    column_labels_border_top_color="blue",
    column_labels_border_top_style="solid",
    column_labels_border_top_width="5px"
)
# Out:
# GT(_tbl_data=         num     char   fctr        date   time          datetime  currency  \
# 0     0.1111  apricot    one  2015-01-15  13:35  2018-01-01 02:22     49.95
# 1     2.2220   banana    two  2015-02-15  14:40  2018-02-02 14:33     17.95
# 2    33.3300  coconut  three  2015-03-15  15:45  2018-03-03 03:44      1.39
# 3   444.4000   durian   four  2015-04-15  16:50  2018-04-04 15:55  65100.00
# 4  5550.0000      NaN   five  2015-05-15  17:55  2018-05-05 04:00   1325.81
#
#      row  group
# 0  row_1  grp_a
# 1  row_2  grp_a
# 2  row_3  grp_a
# 3  row_4  grp_a
# 4  row_5  grp_b  , _body=<great_tables._gt_data.Body object at 0x122a3b910>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='fctr', type=<ColInfoTypeEnum.default: 1>, column_label='fctr', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='right', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a3a650>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b4d650>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True,  ...

# %%
gt_ex.tab_options(
    heading_background_color="purple"
)
# Out:
# GT(_tbl_data=         num     char   fctr        date   time          datetime  currency  \
# 0     0.1111  apricot    one  2015-01-15  13:35  2018-01-01 02:22     49.95
# 1     2.2220   banana    two  2015-02-15  14:40  2018-02-02 14:33     17.95
# 2    33.3300  coconut  three  2015-03-15  15:45  2018-03-03 03:44      1.39
# 3   444.4000   durian   four  2015-04-15  16:50  2018-04-04 15:55  65100.00
# 4  5550.0000      NaN   five  2015-05-15  17:55  2018-05-05 04:00   1325.81
#
#      row  group
# 0  row_1  grp_a
# 1  row_2  grp_a
# 2  row_3  grp_a
# 3  row_4  grp_a
# 4  row_5  grp_b  , _body=<great_tables._gt_data.Body object at 0x122a3b910>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='fctr', type=<ColInfoTypeEnum.default: 1>, column_label='fctr', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='right', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a3a650>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b4d650>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True,  ...

# %%
gt_ex.tab_options(
    table_body_hlines_color="red",
    table_body_hlines_style="dashed",
    table_body_hlines_width="4px",
)
# Out:
# GT(_tbl_data=         num     char   fctr        date   time          datetime  currency  \
# 0     0.1111  apricot    one  2015-01-15  13:35  2018-01-01 02:22     49.95
# 1     2.2220   banana    two  2015-02-15  14:40  2018-02-02 14:33     17.95
# 2    33.3300  coconut  three  2015-03-15  15:45  2018-03-03 03:44      1.39
# 3   444.4000   durian   four  2015-04-15  16:50  2018-04-04 15:55  65100.00
# 4  5550.0000      NaN   five  2015-05-15  17:55  2018-05-05 04:00   1325.81
#
#      row  group
# 0  row_1  grp_a
# 1  row_2  grp_a
# 2  row_3  grp_a
# 3  row_4  grp_a
# 4  row_5  grp_b  , _body=<great_tables._gt_data.Body object at 0x122a3b910>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='fctr', type=<ColInfoTypeEnum.default: 1>, column_label='fctr', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='right', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a3a650>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b4d650>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True,  ...

# %%
gt_ex.tab_options(
    table_body_hlines_style="solid",
    table_body_vlines_style="solid",
)
# Out:
# GT(_tbl_data=         num     char   fctr        date   time          datetime  currency  \
# 0     0.1111  apricot    one  2015-01-15  13:35  2018-01-01 02:22     49.95
# 1     2.2220   banana    two  2015-02-15  14:40  2018-02-02 14:33     17.95
# 2    33.3300  coconut  three  2015-03-15  15:45  2018-03-03 03:44      1.39
# 3   444.4000   durian   four  2015-04-15  16:50  2018-04-04 15:55  65100.00
# 4  5550.0000      NaN   five  2015-05-15  17:55  2018-05-05 04:00   1325.81
#
#      row  group
# 0  row_1  grp_a
# 1  row_2  grp_a
# 2  row_3  grp_a
# 3  row_4  grp_a
# 4  row_5  grp_b  , _body=<great_tables._gt_data.Body object at 0x122a3b910>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='fctr', type=<ColInfoTypeEnum.default: 1>, column_label='fctr', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='right', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a3a650>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b4d650>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True,  ...

# %%
gt_ex.tab_options(
    table_background_color="green",
    table_font_color="darkblue",
    table_font_style="italic",
    table_font_names="Times New Roman"
)
# Out:
# GT(_tbl_data=         num     char   fctr        date   time          datetime  currency  \
# 0     0.1111  apricot    one  2015-01-15  13:35  2018-01-01 02:22     49.95
# 1     2.2220   banana    two  2015-02-15  14:40  2018-02-02 14:33     17.95
# 2    33.3300  coconut  three  2015-03-15  15:45  2018-03-03 03:44      1.39
# 3   444.4000   durian   four  2015-04-15  16:50  2018-04-04 15:55  65100.00
# 4  5550.0000      NaN   five  2015-05-15  17:55  2018-05-05 04:00   1325.81
#
#      row  group
# 0  row_1  grp_a
# 1  row_2  grp_a
# 2  row_3  grp_a
# 3  row_4  grp_a
# 4  row_5  grp_b  , _body=<great_tables._gt_data.Body object at 0x122a3b910>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='fctr', type=<ColInfoTypeEnum.default: 1>, column_label='fctr', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='right', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a3a650>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b4d650>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='green'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['Times New Roman']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='italic'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='darkblue'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), head ...

# %%
gt_ex.tab_options(
    table_background_color="orange",
    heading_background_color="pink"
)
# Out:
# GT(_tbl_data=         num     char   fctr        date   time          datetime  currency  \
# 0     0.1111  apricot    one  2015-01-15  13:35  2018-01-01 02:22     49.95
# 1     2.2220   banana    two  2015-02-15  14:40  2018-02-02 14:33     17.95
# 2    33.3300  coconut  three  2015-03-15  15:45  2018-03-03 03:44      1.39
# 3   444.4000   durian   four  2015-04-15  16:50  2018-04-04 15:55  65100.00
# 4  5550.0000      NaN   five  2015-05-15  17:55  2018-05-05 04:00   1325.81
#
#      row  group
# 0  row_1  grp_a
# 1  row_2  grp_a
# 2  row_3  grp_a
# 3  row_4  grp_a
# 4  row_5  grp_b  , _body=<great_tables._gt_data.Body object at 0x122a3b910>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='fctr', type=<ColInfoTypeEnum.default: 1>, column_label='fctr', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='right', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a3a650>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b4d650>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='orange'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, c ...

# %%
from great_tables import GT, exibble

# TODO: are there names we can give the three colors?
# e.g. primary = "#0076BA", etc..

(GT(exibble, rowname_col="row", groupname_col="group")
    .tab_header("THE HEADING", "(a subtitle)")
    .tab_stubhead("THE STUBHEAD")
    .tab_source_note("THE SOURCE NOTE")
    .tab_options(
        # table ----
        table_border_top_color="#004D80",
        table_border_bottom_color="#004D80",

        # heading ----
        heading_border_bottom_color="#0076BA",

        # column labels ----
        column_labels_border_top_color="#0076BA",
        column_labels_border_bottom_color="#0076BA",
        column_labels_background_color="#FFFFFF",

        # row group ----
        row_group_border_top_color="#0076BA",
        row_group_border_bottom_color="#0076BA",

        # stub ----
        stub_background_color="#0076BA",
        stub_border_style="solid",
        stub_border_color="#0076BA",

        # table body ----
        table_body_border_top_color="#0076BA",
        table_body_border_bottom_color="#0076BA",
        table_body_hlines_style="none",
        table_body_vlines_style="none",

        # misc ----
        #row_striping_background_color="#F4F4F4"
    )

)
# Out:
# GT(_tbl_data=            num        char   fctr        date   time          datetime  \
# 0  1.111000e-01     apricot    one  2015-01-15  13:35  2018-01-01 02:22
# 1  2.222000e+00      banana    two  2015-02-15  14:40  2018-02-02 14:33
# 2  3.333000e+01     coconut  three  2015-03-15  15:45  2018-03-03 03:44
# 3  4.444000e+02      durian   four  2015-04-15  16:50  2018-04-04 15:55
# 4  5.550000e+03         NaN   five  2015-05-15  17:55  2018-05-05 04:00
# 5           NaN         fig    six  2015-06-15    NaN  2018-06-06 16:11
# 6  7.770000e+05  grapefruit  seven         NaN  19:10  2018-07-07 05:22
# 7  8.880000e+06    honeydew  eight  2015-08-15  20:20               NaN
#
#     currency    row  group
# 0     49.950  row_1  grp_a
# 1     17.950  row_2  grp_a
# 2      1.390  row_3  grp_a
# 3  65100.000  row_4  grp_a
# 4   1325.810  row_5  grp_b
# 5     13.255  row_6  grp_b
# 6        NaN  row_7  grp_b
# 7      0.440  row_8  grp_b  , _body=<great_tables._gt_data.Body object at 0x122b812d0>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='fctr', type=<ColInfoTypeEnum.default: 1>, column_label='fctr', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='right', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122a4afd0>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b8d690>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#004D80'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#004D80'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo( ...

# %%
from great_tables import GT, exibble

lil_exibble = exibble.head(5)[["num", "char", "row", "group"]]

gt_ex = (
    GT(lil_exibble, rowname_col="row", groupname_col="group")
    .tab_header("THE HEADING", "(a subtitle)")
    .tab_stubhead("THE STUBHEAD")
    .tab_source_note("THE SOURCE NOTE")
)

gt_ex
# Out:
# GT(_tbl_data=         num     char    row  group
# 0     0.1111  apricot  row_1  grp_a
# 1     2.2220   banana  row_2  grp_a
# 2    33.3300  coconut  row_3  grp_a
# 3   444.4000   durian  row_4  grp_a
# 4  5550.0000      NaN  row_5  grp_b, _body=<great_tables._gt_data.Body object at 0x122b8c3d0>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122b8f450>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b82c10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading',  ...

# %%
gt_ex.opt_stylize(style = 1, color = "blue")
# Out:
# GT(_tbl_data=         num     char    row  group
# 0     0.1111  apricot  row_1  grp_a
# 1     2.2220   banana  row_2  grp_a
# 2    33.3300  coconut  row_3  grp_a
# 3   444.4000   durian  row_4  grp_a
# 4  5550.0000      NaN  row_5  grp_b, _body=<great_tables._gt_data.Body object at 0x122b8c3d0>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122b8f450>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b82c10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#004D80'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#004D80'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading',  ...

# %%
gt_ex.opt_stylize(style = 2, color = "red")
# Out:
# GT(_tbl_data=         num     char    row  group
# 0     0.1111  apricot  row_1  grp_a
# 1     2.2220   banana  row_2  grp_a
# 2    33.3300  coconut  row_3  grp_a
# 3   444.4000   durian  row_4  grp_a
# 4  5550.0000      NaN  row_5  grp_b, _body=<great_tables._gt_data.Body object at 0x122b8c3d0>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122b8f450>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b82c10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#D5D5D5'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#D5D5D5'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading',  ...

# %%
gt_ex.opt_align_table_header(align="left")
# Out:
# GT(_tbl_data=         num     char    row  group
# 0     0.1111  apricot  row_1  grp_a
# 1     2.2220   banana  row_2  grp_a
# 2    33.3300  coconut  row_3  grp_a
# 3   444.4000   durian  row_4  grp_a
# 4  5550.0000      NaN  row_5  grp_b, _body=<great_tables._gt_data.Body object at 0x122b8c3d0>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122b8f450>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b82c10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='left'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', ty ...

# %%
gt_ex.opt_all_caps()
# Out:
# GT(_tbl_data=         num     char    row  group
# 0     0.1111  apricot  row_1  grp_a
# 1     2.2220   banana  row_2  grp_a
# 2    33.3300  coconut  row_3  grp_a
# 3   444.4000   durian  row_4  grp_a
# 4  5550.0000      NaN  row_5  grp_b, _body=<great_tables._gt_data.Body object at 0x122b8c3d0>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122b8f450>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b82c10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading',  ...

# %%
gt_ex.opt_vertical_padding(scale=0.3)
# Out:
# GT(_tbl_data=         num     char    row  group
# 0     0.1111  apricot  row_1  grp_a
# 1     2.2220   banana  row_2  grp_a
# 2    33.3300  coconut  row_3  grp_a
# 3   444.4000   durian  row_4  grp_a
# 4  5550.0000      NaN  row_5  grp_b, _body=<great_tables._gt_data.Body object at 0x122b8c3d0>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122b8f450>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b82c10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading',  ...

# %%
gt_ex.opt_horizontal_padding(scale=3)
# Out:
# GT(_tbl_data=         num     char    row  group
# 0     0.1111  apricot  row_1  grp_a
# 1     2.2220   banana  row_2  grp_a
# 2    33.3300  coconut  row_3  grp_a
# 3   444.4000   durian  row_4  grp_a
# 4  5550.0000      NaN  row_5  grp_b, _body=<great_tables._gt_data.Body object at 0x122b8c3d0>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122b8f450>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b82c10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading',  ...

# %%
gt_ex.opt_table_outline()
# Out:
# GT(_tbl_data=         num     char    row  group
# 0     0.1111  apricot  row_1  grp_a
# 1     2.2220   banana  row_2  grp_a
# 2    33.3300  coconut  row_3  grp_a
# 3   444.4000   durian  row_4  grp_a
# 4  5550.0000      NaN  row_5  grp_b, _body=<great_tables._gt_data.Body object at 0x122b8c3d0>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.stub: 2>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.row_group: 3>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x122b8f450>, _spanners=Spanners([]), _heading=Heading(title='THE HEADING', subtitle='(a subtitle)', preheader=None), _stubhead='THE STUBHEAD', _source_notes=['THE SOURCE NOTE'], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x122b82c10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='3px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='3px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='3px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='3px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading' ...
